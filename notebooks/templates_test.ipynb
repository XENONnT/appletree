# %%
import os
os.environ['DO_NOT_USE_APPROX_IN_BINOM'] = '1'

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from matplotlib.colors import LogNorm, Normalize

import appletree as apt

from nton.cevns.templates import Templates
# Out:
# No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# Using accurate Binomial, not Normal approximation
# /home/xudc/appletree/appletree/__init__.py:44: UserWarning: You are running appletree on CPU, which usually results in low performance.
#   warn(warning)
# Using aptext package from https://github.com/XENONnT/applefiles
# *** Detector definition message ***
# You are currently using the default XENON10 template detector.
# ^ Awesome table ^^^^
# ^ module ^ version ^ path ^ git ^
# | python | 3.9.17 | /opt/XENONnT/anaconda/envs/XENONnT_2023.07.1/bin/python | None |
# | strax | 1.5.2 | /home/xudc/strax/strax | branch:unknown | 2fb4d1d |
# | straxen | 2.1.2 | /home/xudc/straxen/straxen | branch:unknown | 3258746 |
# | cutax | 1.15.3 | /home/xudc/cutax/cutax | branch:hot_spot | 99af85b |
# | wfsim | 1.0.2 | /opt/XENONnT/anaconda/envs/XENONnT_2023.07.1/lib/python3.9/site-packages/wfsim | None |
# ...

# %%
matplotlib.style.use('default')
plt.rcParams['savefig.dpi'] = 100
plt.rcParams['figure.dpi'] = 100
plt.rcParams['font.size'] = 15
plt.rcParams['legend.fontsize'] = 15
plt.rcParams['xtick.labelsize'] = 15
plt.rcParams['ytick.labelsize'] = 15
plt.rcParams['axes.labelsize'] = 15
plt.rcParams['lines.linewidth'] = 2.0
plt.rcParams['patch.linewidth'] = 2.0
plt.rcParams['axes.grid'] = False

# %%
output_dir = '/home/xudc/scratch-midway2/nton/Templates_bk/output'
# plot_dir = '/home/xudc/scratch-midway2/nton/Templates_bk/output/plots'

A = Templates(s2_bdt_quantile=0.8, output_dir=output_dir)
# Out:
# INFO:analysis_logger:Using logging dir: /scratch/midway2/xudc/nton/Templates/logs
# INFO:analysis_logger:Using output dir: /home/xudc/scratch-midway2/nton/Templates_bk/output
# INFO:analysis_logger:Using container: /project2/lgrandi/xenonnt/singularity-images/xenonnt-development.simg
# Set s2_bdt_quantile to 0.8
# You specified _auto_append_rucio_local=True and you are not on dali compute nodes,so we will add the following rucio local path:  /project/lgrandi/rucio/
# INFO:strax:Replacing context._fixed_plugin_cache since plugins/versions changed
# /home/xudc/appletree/appletree/utils.py:161: UserWarning: Load cevns.json successfully from /home/xudc/scratch-midway2/nton/Templates_bk/output/cevns.json
#   warn(f"Load {fname} successfully from {fpath}")

# %%
A.plot_light_charge_yields()
A.plot_templates_comparison()
# Out:
# B8 template is 4.892/t/y
# AC template is 13.116/t/y
# NR template is 0.019/t/y
# ER template is 0.075/t/y
# ^ Components' Rate ^^^^
# ^ B8 ^ AC ^ NR ^ ER ^
# | 4.89 | 13.12 | 0.02 | 0.08 |
# 100%|██████████| 6/6 [00:02<00:00,  2.15it/s]
# ^  ^ B8 (/t/y) ^ AC (/t/y) ^
# | 2hits + bottom hits < 2 + LHA < 2 | 1.19 | 6.72 |
# | 2hits + bottom hits < 2 + LHA >= 2 | 0.36 | 0.28 |
# | 2hits + bottom hits >= 2 + LHA < 2 | 1.46 | 3.54 |
# | 2hits + bottom hits >= 2 + LHA >= 2 | 0.44 | 0.25 |
# | 3hits + LHA < 2 | 0.97 | 1.72 |
# | 3hits + LHA >= 2 | 0.47 | 0.60 |

# %% [markdown]
# # Check simulation results

# %%
key = apt.randgen.get_key(seed=A.seed)

# %%
name = 'cevns'

# %%
parameters, component = A.get_components_parameters(name)
# Out:
# /home/xudc/appletree/appletree/utils.py:161: UserWarning: Load XENONnT_NROnlyFit_parameters.json successfully from /home/xudc/scratch-midway2/nton/Templates_bk/output/XENONnT_NROnlyFit_parameters.json
#   warn(f"Load {fname} successfully from {fpath}")
# /home/xudc/appletree/appletree/utils.py:161: UserWarning: Load cevns_spectrum.json successfully from /home/xudc/scratch-midway2/nton/Templates_bk/output/cevns_spectrum.json
#   warn(f"Load {fname} successfully from {fpath}")
# /home/xudc/appletree/appletree/utils.py:161: UserWarning: Load nr_qy_median.json successfully from /home/xudc/scratch-midway2/nton/Templates_bk/output/nr_qy_median.json
#   warn(f"Load {fname} successfully from {fpath}")
# /home/xudc/appletree/appletree/utils.py:161: UserWarning: Load nr_qy_lower.json successfully from /home/xudc/scratch-midway2/nton/Templates_bk/output/nr_qy_lower.json
#   warn(f"Load {fname} successfully from {fpath}")
# ...

# %%
key, result = A.run_simulation(key, component, parameters)

# %%
result
# Out:
# array([(2,  28.527891, 0.00023359, 0.8705852 , 2.87     , 1, 20, 0.6068784 , 0.       ),
#        (2,  61.64826 , 0.00060311, 0.88570803, 1.4673477, 2, 40, 0.95565546, 0.       ),
#        (2,  46.289806, 0.00103676, 0.9150733 , 2.06     , 2, 40, 0.99338204, 0.       ),
#        ...,
#        (3, 132.62144 , 0.0014705 , 0.9314334 , 1.41     , 3, 70, 1.0104733 , 0.       ),
#        (3, 104.84606 , 0.00038955, 0.91509897, 1.4752516, 3, 70, 1.8833154 , 0.6532546),
#        (2,  22.360937, 0.0098318 , 0.90954906, 2.4      , 1, 20, 0.36286086, 0.       )],
#       dtype=[('s1_n_hits', 'i1'), ('s2_area', '<f4'), ('s2_shadow_s2_time_shadow', '<f4'), ('s2_bdt_score', '<f4'), ('s1_max_pmt_area', '<f4'), ('s1_bottom_n_channels', 'i1'), ('s1_max_diff', '<i2'), ('energy', '<f4'), ('eff', '<f4')])

# %%
result['s1_bottom_n_channels'][result['s1_n_hits'] == 2].max()
# Out:
# 2
