# %%
from microphys import *
from par_manager import ParManager
import utils
import randgen

from jax import jit
from functools import partial

# %%
utils.set_gpu_memory_usage(0.2)

# %%
key = randgen.get_key()

# %%
par = ParManager()

# %%
plugin1 = EnergySpectra(par, 0.01, 10.)
plugin2 = Quenching(par)
plugin3 = Ionization(par)
plugin4 = mTI(par)
plugin5 = RecombFluct(par)
plugin6 = TrueRecomb(par)
plugin7 = Recombination(par)

# %%
@utils.timeit
# @partial(jit, static_argnums=(1, ))
def sim(key, n):
    key, energy = plugin1(key, n)
    key, nq = plugin2(key, energy)
    key, ni = plugin3(key, nq)
    
    key, r_mean = plugin4(key, energy)
    key, r_std = plugin5(key, energy)
    key, r = plugin6(key, r_mean, r_std)
    
    key, n_ph, n_e = plugin7(key, nq, ni, r)
    return key, n_ph, n_e

# %%
key, _, _ = sim(key, int(1e6))
# Out:
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 1.765490 msec.

# %%
@utils.timeit
def f():
    key = randgen.get_key()
    for _ in range(100):
        key, _, _ = sim(key, int(1e6))

# %%
f()
# Out:
#  Function <f> starts.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 6.159544 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.961065 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.678062 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.658274 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 1.996517 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.689268 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.650406 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.599384 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.627756 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 1.442194 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.865459 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.605345 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.497103 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 2.016068 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.738144 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.603199 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.542641 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.407934 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 2.074003 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.744820 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.345230 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.405550 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.299454 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 3.912687 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.761509 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.459671 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.282526 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 3.998041 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.808477 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.367641 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.347853 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.530481 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 1.832247 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.752926 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.600100 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.424385 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 2.094746 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.738621 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.466108 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.550508 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.534773 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 2.068281 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.766993 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.605583 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.425577 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.550270 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 1.971483 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.813723 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.363111 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.407457 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 2.274513 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.735760 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.350475 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.552893 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.496387 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 1.894236 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.711441 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.569582 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.308514 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.387669 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 1.650810 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.717402 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.325680 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.300407 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 2.661228 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.718832 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.312805 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.305414 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.405788 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 2.087116 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.535965 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.307083 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.518322 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 6.915808 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.773430 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.654697 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.354290 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.523806 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 4.150629 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.800610 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.378847 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.678301 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 2.074242 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.876665 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.707626 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.667810 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.658274 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 1.599550 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.883102 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.683784 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.684500 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 3.997326 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.805855 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.621796 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.568628 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.450850 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 3.683329 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.845432 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.431299 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.625849 msec.
#  Function <f> ends! Time cost = 124.045134 msec.

# %%
for _ in range(100):
    key, _, _ = sim(key, int(1e6))
# Out:
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.663757 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.464678 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.439644 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.429153 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.391483 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.403404 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.439882 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.374794 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.455618 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.433683 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.381470 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.387669 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.391960 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.387669 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.383854 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.373602 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.427485 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.432253 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.382900 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.396490 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.389814 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.363827 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.426769 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.423670 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.409842 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.405312 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.391006 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.398874 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.395060 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.346184 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.408649 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.371695 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.354290 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.427246 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.412464 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.426769 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.379324 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.413418 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.402212 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.361443 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.385284 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.365257 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.375032 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.384092 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.365496 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.377655 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.339031 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.397682 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.394583 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.397205 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.400066 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.398159 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.393629 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.389814 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.405550 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.460148 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.377893 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.429392 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.410795 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.411749 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.367403 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.361919 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.388622 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.391722 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.442028 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.422716 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.386238 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.443697 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.380039 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.352383 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.361681 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.381947 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.345945 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.354052 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.391722 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.394106 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.356197 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.403881 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.440598 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.364780 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 1.276016 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.409126 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.428200 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.396967 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.396490 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.374794 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.433445 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 3.594875 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.397921 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.417471 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.412226 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.383615 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.398636 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 3.953695 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.380516 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.387192 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.367165 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.364542 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 0.380993 msec.
#  Function <sim> starts.
#  Function <sim> ends! Time cost = 2.653122 msec.
